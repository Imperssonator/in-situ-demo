# %% [markdown]
# # NSLS 11-BM Calibration

# %% [markdown]
# ### Import python libraries

# %%
# numpy and plotting
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Data handling
import glob
import os
import pandas as pd

# pyFAI
import pyFAI
from pyFAI.calibrant import get_calibrant

# pygix
import pygix
import fabio
from pygix import plotting as ppl

# Peak Fitting, optimization
from lmfit.models import GaussianModel, LorentzianModel, ExponentialModel, ConstantModel, LinearModel, VoigtModel
from scipy.optimize import minimize
from scipy.signal import medfilt

# Fix MPL params
rcParams.update({'figure.autolayout': True,
                 'xtick.top': True,
                 'xtick.direction': 'in',
                 'ytick.right': True,
                 'ytick.direction': 'in',
                 'font.sans-serif': 'Arial',
                 'font.size': 14
                })
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['figure.dpi'] = 96
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ### Load data & metadata files

# %%
base_folder = "\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS"
edf_glob = glob.glob(os.path.join(base_folder,'*.edf'))
print(edf_glob[0])
# Out:
# \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Data\ALS 7.3.3\2018_May\WAXS\AgB_2m.edf

# %%
pd.read_table(txt_glob[0], sep=":", engine='c', header=None, index_col=0, skiprows=3, nrows=95).T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-5be4484772cb> in <module>()
# ----> 1 pd.read_table(txt_glob[0], sep=":", engine='c', header=None, index_col=0, skiprows=3, nrows=95).T
#
# NameError: name 'txt_glob' is not defined

# %%
df = pd.DataFrame()
df['edf'] = edf_glob
df['txt'] = df['edf'].str.replace('edf','txt')
df
# Out:
#                                                   edf  \
# 0   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 1   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 2   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 3   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 4   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 5   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 6   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 7   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 8   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 9   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 10  \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 11  \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
#
#                                                   txt
# 0   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 1   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 2   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 3   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 4   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 5   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 6   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 7   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 8   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 9   \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 10  \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...
# 11  \\cfs2e.nist.gov\63_mml\642\users\saxs8542\Dat...

# %%
meta = df.apply(lambda r: pd.read_table(r['txt'], sep=":", engine='c',
                                              header=None, index_col=0,
                                              skiprows=3, nrows=95).T,
                               axis=1)
meta.loc[1].loc[1]
# Out:
# 0
# Motors                           53.000000
# Sample X Stage                   35.287000
# Sample Y Stage                   28.106038
# Sample Y Stage Robot              0.000000
# Sample X Stage fine             -49.380800
# Sample Y Stage fine               5.733929
# Sample Alpha Stage                0.160803
# Sample Phi Stage                  0.116426
# Sample Rotation Stage             0.000000
# M201 Feedback                    -0.001739
# M1 Pitch                          0.107148
# M1 Bend                          50.344796
# Detector Horizontal               0.000000
# Detector Vertical                 0.000000
# Slit1 top                         8.990500
# Slit1 bottom                     11.972500
# Slit1 right                      11.680000
# Slit1 left                        9.814000
# Exit Slit top                     5.981500
# Exit Slit bottom                 12.861500
# Exit Slit left                   11.137500
# Exit Slit right                   4.463000
# GIWAXS beamstop X                 0.000000
# GIWAXS beamstop Y                 0.000000
# Beamstop X                        0.000000
# Beamstop Y                        0.000000
# Detector Left Motor               0.000000
# Detector Right Motor              0.000000
# Motorized Lab Jack                8.584766
# M1 Alignment Tune                 0.107148
# print head height                 0.000000
# Rotation New                      0.000000
# printer roll                      0.000000
# EZ fast tension stage             0.000000
# Motorized Lab Jack1               0.000000
# Sample Rotation Stage ESP         0.000000
# Printing motor                    0.000000
# GIWAXS beamstop Y thorlabs        0.000000
# Sample Y Stage Arthur             0.000000
# Flight Tube Horizontal            0.000000
# Flight Tube Vertical              0.000000
# Hacked Ager Stage                 0.000000
# Sample Rotation Stage Miller      0.000000
# Mono Angle                        0.000000
# Xtal2 Pico 1 Feedback             0.000000
# Xtal2 Pico 2 Feedback             0.000000
# Xtal2 Pico 3 Feedback             0.000000
# Xtal2 Pico 1                      0.000000
# Xtal2 Pico 2                      0.000000
# Xtal2 Pico 3                      0.000000
# Sample Y Stage_old                0.000000
# AO Waveform                       0.000000
# BAlpha_scan_positions=                 NaN
# Alpha_scan_I0_intensities=             NaN
# Alpha_scan_I1_intensities=             NaN
# Alpha_scan_diode_intensities=          NaN
# Name: 1, dtype: float64

# %%
df = pd.concat(df,
               df['txt'].apply(lambda f: pd.read_table(f, sep=":", engine='c',
                                      header=None, index_col=0,
                                      skiprows=3, nrows=95).T)
              )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-9f0f8cae1d0a> in <module>()
#       1 df = pd.concat(df,
# ----> 2                df['txt'].apply(lambda f: pd.read_table(f, sep=":", engine='c',
#       3                                       header=None, index_col=0,
#       4                                       skiprows=3, nrows=95).T)
#       5               )
#
# ~\anaconda3\envs\xray\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~\anaconda3\envs\xray\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     239             raise TypeError('first argument must be an iterable of pandas '
#     240                             'objects, you passed an object of type '
# --> 241                             '"{name}"'.format(name=type(objs).__name__))
#     242
#     243         if join == 'outer':
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
new
# Out:
# 0     0 Motors Sample X Stage Sample Y Stage Sample ...
# 1     0  Motors  Sample X Stage  Sample Y Stage  Sam...
# 2     0 Motors Sample X Stage Sample Y Stage Sample ...
# 3     0 Motors Sample X Stage Sample Y Stage Sample ...
# 4     0 Motors Sample X Stage Sample Y Stage Sample ...
# 5     0 Motors Sample X Stage Sample Y Stage Sample ...
# 6     0 Motors Sample X Stage Sample Y Stage Sample ...
# 7     0 Motors Sample X Stage Sample Y Stage Sample ...
# 8     0 Motors Sample X Stage Sample Y Stage Sample ...
# 9     0 Motors Sample X Stage Sample Y Stage Sample ...
# 10    0 Motors Sample X Stage Sample Y Stage Sample ...
# 11    0  Motors  Sample X Stage  Sample Y Stage  Sam...
# Name: txt, dtype: object

# %%
# %matplotlib notebook
test_img = fabio.open(edf_glob[0]).data
plt.imshow(test_img, cmap='terrain')
# Out:
# <img src="data:image/png;base64,..." width="312">

# %% [markdown]
# ## Master dataframe for background files

# %%
df = build_master_table(raw_files)
df
# Out:
#                                                   tiff         sample solvent  \
# 0    /Users/nils/CC/N2200/data/nsls/AgBH_5m_cali_2_...   AgBH_5m_cali    AgBH
# 1    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_10_...    Tol_fast_ng     Tol
# 2    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_11_...    Tol_fast_ng     Tol
# 3    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_12_...    Tol_fast_ng     Tol
# 4    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_13_...    Tol_fast_ng     Tol
# 5    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_14_...    Tol_fast_ng     Tol
# 6    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_15_...    Tol_fast_ng     Tol
# 7    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_16_...    Tol_fast_ng     Tol
# 8    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_17_...    Tol_fast_ng     Tol
# 9    /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_18_...    Tol_fast_ng     Tol
# 10   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_19_...    Tol_fast_ng     Tol
# 11   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_1_t...    Tol_fast_ng     Tol
# 12   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_20_...    Tol_fast_ng     Tol
# 13   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_21_...    Tol_fast_ng     Tol
# 14   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_22_...    Tol_fast_ng     Tol
# 15   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_23_...    Tol_fast_ng     Tol
# 16   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_25_...    Tol_fast_ng     Tol
# 17   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_26_...    Tol_fast_ng     Tol
# 18   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_27_...    Tol_fast_ng     Tol
# 19   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_28_...    Tol_fast_ng     Tol
# 20   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_29_...    Tol_fast_ng     Tol
# 21   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_2_t...    Tol_fast_ng     Tol
# 22   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_30_...    Tol_fast_ng     Tol
# 23   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_31_...    Tol_fast_ng     Tol
# 24   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_32_...    Tol_fast_ng     Tol
# 25   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_33_...    Tol_fast_ng     Tol
# 26   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_34_...    Tol_fast_ng     Tol
# 27   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_35_...    Tol_fast_ng     Tol
# 28   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_36_...    Tol_fast_ng     Tol
# 29   /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_37_...    Tol_fast_ng     Tol
# ..                                                 ...            ...     ...
# 305  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_4...  Tol_spun_run2     Tol
# 306  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_4...  Tol_spun_run2     Tol
# 307  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 308  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 309  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 310  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 311  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 312  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 313  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 314  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 315  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 316  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_5...  Tol_spun_run2     Tol
# 317  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 318  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 319  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 320  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 321  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 322  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 323  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 324  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 325  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_6...  Tol_spun_run2     Tol
# 326  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 327  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 328  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 329  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 330  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 331  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 332  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 333  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_7...  Tol_spun_run2     Tol
# 334  /Users/nils/CC/N2200/data/nsls/Tol_spun_run2_9...  Tol_spun_run2     Tol
#
#     speed grooves shot  theta      phi  exp_time   stamp
# 0      5m    cali    2   0.00   -0.000       5.0  325173
# 1    fast      ng   10   0.18   90.001      15.0  323612
# 2    fast      ng   11   0.14    0.000      15.0  323613
# 3    fast      ng   12   0.14    3.001      15.0  323614
# 4    fast      ng   13   0.14    6.001      15.0  323615
# 5    fast      ng   14   0.14    9.001      15.0  323616
# 6    fast      ng   15   0.14   12.001      15.0  323617
# 7    fast      ng   16   0.14   15.001      15.0  323618
# 8    fast      ng   17   0.14   18.001      15.0  323619
# 9    fast      ng   18   0.14   21.001      15.0  323620
# 10   fast      ng   19   0.14   24.001      15.0  323621
# 11   fast      ng    1   0.09    0.001      15.0  323603
# 12   fast      ng   20   0.14   27.001      15.0  323622
# 13   fast      ng   21   0.14   30.002      15.0  323623
# 14   fast      ng   22   0.14   33.002      15.0  323624
# 15   fast      ng   23   0.14   36.002      15.0  323625
# 16   fast      ng   25   0.14   42.002      15.0  323627
# 17   fast      ng   26   0.14   45.002      15.0  323628
# 18   fast      ng   27   0.14   48.002      15.0  323629
# 19   fast      ng   28   0.14   51.003      15.0  323630
# 20   fast      ng   29   0.14   54.003      15.0  323631
# 21   fast      ng    2   0.11    0.001      15.0  323604
# 22   fast      ng   30   0.14   57.003      15.0  323632
# 23   fast      ng   31   0.14   60.003      15.0  323633
# 24   fast      ng   32   0.14   63.003      15.0  323634
# 25   fast      ng   33   0.14   66.004      15.0  323635
# 26   fast      ng   34   0.14   69.004      15.0  323636
# 27   fast      ng   35   0.14   72.004      15.0  323637
# 28   fast      ng   36   0.14   75.004      15.0  323638
# 29   fast      ng   37   0.14   78.004      15.0  323639
# ..    ...     ...  ...    ...      ...       ...     ...
# 305  spun    run2   49   0.14   99.006      15.0  328458
# 306  spun    run2    4   0.15  -89.999       5.0  328413
# 307  spun    run2   50   0.14  102.006      15.0  328459
# 308  spun    run2   51   0.14  105.006      15.0  328460
# 309  spun    run2   52   0.14  108.007      15.0  328461
# 310  spun    run2   53   0.14  111.007      15.0  328462
# 311  spun    run2   54   0.14  114.007      15.0  328463
# 312  spun    run2   55   0.14  117.007      15.0  328464
# 313  spun    run2   56   0.14  120.007      15.0  328465
# 314  spun    run2   57   0.14  123.007      15.0  328466
# 315  spun    run2   59   0.14  129.008      15.0  328468
# 316  spun    run2    5   0.18  -89.999       5.0  328414
# 317  spun    run2   60   0.14  132.008      15.0  328469
# 318  spun    run2   61   0.14  135.008      15.0  328470
# 319  spun    run2   62   0.14  138.008      15.0  328471
# 320  spun    run2   63   0.14  141.009      15.0  328472
# 321  spun    run2   65   0.14  147.009      15.0  328474
# 322  spun    run2   66   0.14  150.009      15.0  328475
# 323  spun    run2   67   0.14  153.010      15.0  328476
# 324  spun    run2   68   0.14  156.010      15.0  328477
# 325  spun    run2   69   0.14  159.010      15.0  328478
# 326  spun    run2   70   0.14  162.010      15.0  328479
# 327  spun    run2   71   0.14  165.010      15.0  328480
# 328  spun    run2   72   0.14  168.010      15.0  328481
# 329  spun    run2   73   0.14  171.011      15.0  328482
# 330  spun    run2   74   0.14  174.011      15.0  328483
# 331  spun    run2   75   0.14  177.011      15.0  328484
# 332  spun    run2   76   0.14  180.011      15.0  328485
# 333  spun    run2    7   0.11    0.000      15.0  328416
# 334  spun    run2    9   0.15    0.000      15.0  328418
#
# [335 rows x 10 columns]

# %% [markdown]
# ## Calibration

# %%
# %matplotlib notebook

det_shape = (1042,1042)

calib_data = fabio.open(df.loc[0].tiff)
calib_array = np.array(calib_data.data).reshape(det_shape)

lmin, lmax = np.percentile(calib_array, (2, 99.9))
plt.figure(figsize=(4,4))
plt.imshow(calib_array, cmap='terrain',
           vmin=lmin, vmax=lmax,
           origin='upper')
# Out:
# WARNING:fabio.TiffIO:Bogus StripByteCounts information
# <img src="data:image/png;base64,..." width="384">

# %% [markdown]
# ### Beam center looks like [966,7]

# %%
# NSLS-II is a photon Science CCD
 
# 1042x1042 with 0.1017 mm pixels
# 11 keV
# nominally 228.8 mm
# has ~ 16 degree horizontal tilt
# has a ~ 995 count offset

### Starting beam position
sdd_guess = 0.2288
center_guess = [966,7] # -y, +x

### Detector pixel size
det_pix = [101.7e-6, 101.7e-6]
detector = pyFAI.detectors.Detector(det_pix[0], det_pix[1])

### Wavelength
wl = 1.127e-10

### Silver whatever calibrant
agbh = get_calibrant('AgBh')
agbh._wavelength = wl
vars(agbh)
# Out:
# {'_filename': '/anaconda/envs/pygix/lib/python3.6/site-packages/pyFAI/utils/../resources/calibration/AgBh.D',
#  '_wavelength': 1.127e-10,
#  '_sem': <threading.Semaphore at 0x1c18d418d0>,
#  '_2th': [],
#  '_dSpacing': []}

# %% [markdown]
# ## Compare real calibration image to fake one

# %%
### Give initial guess of center location (in meters from the image origin i.e top left)
poni1_guess = center_guess[0]*det_pix[0]
poni2_guess = center_guess[1]*det_pix[1]

### Have to define an "azi integrator" then it can generate fake image of the calibrant
ai = pyFAI.AzimuthalIntegrator(dist=sdd_guess, poni1=poni1_guess, poni2=poni2_guess,
                               detector=detector, wavelength=wl)
fake = agbh.fake_calibration_image(ai, shape = det_shape)

### Plot the real calibration image next to fake one
cmin, cmax = np.percentile(fake, (2, 99.9))
plt.figure(figsize=(8,4))
plt.subplot(1,2,2)
plt.imshow(fake, cmap='terrain',
           vmin=cmin, vmax=cmax,
           origin='upper')
plt.subplot(1,2,1)
plt.imshow(calib_array, cmap='terrain',
           vmin=lmin, vmax=lmax,
           origin='upper')
# Out:
# <img src="data:image/png;base64,..." width="768">

# %% [markdown]
# ## Define an optimizer that will fit a fake ring to a real ring
# Looks like we should target the first ring, so we need to define mask bounds so we don't try to fit every ring

# %%
def calib_obj_fun(x, calib_img, detector, calibrant, bb, wl, det_shape):
    
    # x: [beam_cent_y, beam_cent_x, sdd, fake_scale]
    # bb is mask bounds [-i, +i, -j, +j]
    
    # Set up test detector
    poni1 = x[0]*detector.get_pixel1()
    poni2 = x[1]*detector.get_pixel2()
    ai = pyFAI.AzimuthalIntegrator(dist=x[2], poni1=poni1, poni2=poni2,
                                   detector=detector, wavelength=wl)
    
    # Generate fake calibrant image, apply scale and background
    fake = calibrant.fake_calibration_image(ai, shape = det_shape) * x[3] + x[4]
    
    # Return the sum of the difference
    out = np.abs(np.sum(np.sum((calib_img-fake)[bb[0]:bb[1],bb[2]:bb[3]])))
    print('Residual: {}'.format(out))
    return out


def calibrate_waxs(calib_img, detector, calibrant, cent_init, sdd_init, scale_init, wl, det_shape, mask_bounds):
    
    init_params = [cent_init[0], cent_init[1], sdd_init, scale_init[0], scale_init[1]]
    args = (calib_img, detector, calibrant, mask_bounds, wl, det_shape)
    
    final_params = minimize(calib_obj_fun, init_params,
                            args=args, method='Nelder-Mead', tol=1e-3,
                            options={'disp':True})
    
    return final_params

# %%
mask_bounds = [870, 920, 50, 100] # indices of a box around a ring sector: [i-, i+, j-, j+]
scale_init = [8300, 1200] # scale + background... just estimate from image plot above
det_params = calibrate_waxs(calib_array, detector, agbh, center_guess, sdd_guess, scale_init, wl, det_shape, mask_bounds)
det_params
# Out:
# Residual: 9319190.77979108
# Residual: 9668595.42774949
# Residual: 9327937.82963726
# Residual: 9729652.364848468
# Residual: 9859956.918780632
# Residual: 9469190.77979108
# Residual: 9216025.042458694
# Residual: 9079634.462482601
# Residual: 9668102.173083253
# Residual: 9816865.688151693
# Residual: 10153177.708752835
# Residual: 8991283.365819363
# Residual: 8986838.032413527
# Residual: 9066283.365819363
# Residual: 9547883.72397837
# Residual: 9639985.438423326
# Residual: 8580975.249135152
# Residual: 9352712.969918586
# Residual: 9008645.849561129
# Residual: 9844239.726123797
# Residual: 8846475.700893296
# Residual: 8465317.78627991
# Residual: 8477258.945987616
# Residual: 9330897.009007636
# Residual: 8653102.648120945
# Residual: 8439453.280484041
# Residual: 8547344.495131657
# Residual: 8497931.124602705
# Residual: 9352987.789184112
# Residual: 8490977.64193971
# Residual: 8233147.133957167
# Residual: 8022702.692561132
# Residual: 8078895.553402439
# Residual: 8371984.08695038
# Residual: 8161964.963429699
# Residual: 7858429.968353416
# Residual: 7555037.630915053
# Residual: 7560154.513620606
# Residual: 7751166.603192663
# Residual: 7397253.132116374
# Residual: 7082723.795432899
# Residual: 6999056.909697935
# Residual: 6450726.646434618
# Residual: 6437207.549232449
# Residual: 5646163.273386409
# Residual: 6474915.915179684
# Residual: 5623095.434996246
# Residual: 4652830.180919366
# Residual: 4514699.989922392
# Residual: 3020552.9366610534
# Residual: 3300838.66499856
# Residual: 2930838.5982684693
# Residual: 1212585.892145654
# Residual: 675961.4379947325
# Residual: 2170939.4444314507
# Residual: 560828.9282442818
# Residual: 3683958.351803488
# Residual: 1676391.8720693209
# Residual: 2336150.6006954783
# Residual: 4468243.617748996
# Residual: 1219315.6938968438
# Residual: 2594637.819829768
# Residual: 1078188.3331742084
# Residual: 2238057.3285646224
# Residual: 699115.9145981477
# Residual: 1497928.8750865934
# Residual: 558353.0093725728
# Residual: 1578797.584306368
# Residual: 464342.29018714797
# Residual: 1233729.2796022964
# Residual: 493272.40444990684
# Residual: 948290.0445708144
# Residual: 285508.22987137374
# Residual: 833847.732309312
# Residual: 306450.5641759081
# Residual: 802871.710608378
# Residual: 227580.83668778467
# Residual: 667282.4830547477
# Residual: 255056.71008253668
# Residual: 691596.8949938432
# Residual: 196544.21129346458
# Residual: 500744.4027542644
# Residual: 212553.25955472968
# Residual: 410168.0501706603
# Residual: 129239.94143102333
# Residual: 353819.90731944784
# Residual: 125786.26221024885
# Residual: 340870.96639525786
# Residual: 106542.60413303942
# Residual: 281588.06606993556
# Residual: 101746.44285992952
# Residual: 282328.8298269049
# Residual: 86635.30831976107
# Residual: 233620.08012189757
# Residual: 88705.54343110562
# Residual: 179808.44476732184
# Residual: 52375.42345353839
# Residual: 147707.0124060034
# Residual: 57439.67298094253
# Residual: 150556.99476570747
# Residual: 42352.955422083964
# Residual: 116389.20398752205
# Residual: 47455.8710453097
# Residual: 119075.12353270414
# Residual: 36737.57347903756
# Residual: 104360.41994209506
# Residual: 38492.509493808786
# Residual: 77038.06062308338
# Residual: 23820.471167162934
# Residual: 63474.872986984614
# Residual: 23482.313672897406
# Residual: 65070.85170575202
# Residual: 19369.56696786289
# Residual: 49603.295058162475
# Residual: 19379.297873600444
# Residual: 53104.20180946606
# Residual: 15515.34342227719
# Residual: 42777.61287328671
# Residual: 16847.24208837637
# Residual: 32687.36416181433
# Residual: 9695.317693641235
# Residual: 27934.578749982815
# Residual: 10641.893708739837
# Residual: 27294.15382410778
# Residual: 7712.856199723028
# Residual: 22315.712261895416
# Residual: 8955.45735475712
# Residual: 22926.21444006916
# Residual: 6902.716494346154
# Residual: 18356.532322936866
# Residual: 7033.072007187409
# Residual: 14974.401990156446
# Residual: 4240.757344897895
# Residual: 10948.036226865253
# Residual: 4535.418320307101
# Residual: 11977.77155960002
# Residual: 3723.4764559839386
# Residual: 9270.001419546083
# Residual: 3467.5265601347783
# Residual: 10006.576295062376
# Residual: 2770.2551118175033
# Residual: 7789.296612242295
# Residual: 3229.3075544267776
# Residual: 5946.078517258051
# Residual: 1915.2026093367604
# Residual: 5294.375989770051
# Residual: 1857.4398889193544
# Residual: 4904.270098575158
# Residual: 1566.783334788517
# Residual: 4301.18964599719
# Residual: 1525.3855170500465
# Residual: 4297.440616031701
# Residual: 1347.5444748742739
# Residual: 3347.673736012948
# Residual: 1240.3298276194837
# Residual: 2598.8572144996724
# Residual: 786.7478359889355
# Residual: 2231.8835715022287
# Residual: 835.1912486099754
# Residual: 2153.527512643428
# Residual: 636.7407523483853
# Residual: 1803.6189106517704
# Residual: 693.1518536318326
# Residual: 1885.5630138200358
# Residual: 539.2740878157201
# Residual: 1413.845833998872
# Residual: 576.682569950528
# Residual: 1112.4413199277478
# Residual: 348.3162459206069
# Residual: 963.6205405035871
# Residual: 349.18468492879765
# Residual: 933.174710042309
# Residual: 286.5558124371455
# Residual: 766.0281438586535
# Residual: 286.0419715864118
# Residual: 792.4826321786968
# Residual: 234.37437579181278
# Residual: 632.8691117053968
# Residual: 246.2037483555614
# Residual: 483.93910637230147
# Residual: 140.90377047262155
# Residual: 409.20420411787927
# Residual: 158.95809353759978
# Residual: 398.48321287409635
# Residual: 115.26494865154382
# Residual: 334.64788243506337
# Residual: 130.8531648790231
# Residual: 340.94498067261884
# Residual: 99.46246337442426
# Residual: 273.1394768880564
# Residual: 107.45960307965288
# Residual: 218.32061399205122
# Residual: 64.65505084441975
# Residual: 163.7338257433148
# Residual: 64.74439421249554
# Residual: 180.20975700806594
# Residual: 53.104924212093465
# Residual: 133.35356403625337
# Residual: 53.12288547854405
# Residual: 147.3239946854883
# Residual: 43.765650185989216
# Residual: 116.890004206507
# Residual: 45.3728354354389
# Residual: 89.94896649935981
# Residual: 26.07425772032002
# Residual: 75.68264879472554
# Residual: 29.55412359064212
# Residual: 73.63052681135014
# Residual: 21.449551753001288
# Residual: 62.47211557079572
# Residual: 24.22440697508864
# Residual: 63.15173396823229
# Residual: 18.195871893200092
# Residual: 50.7739143386716
# Residual: 20.148283986665774
# Residual: 40.33623931888724
# Residual: 12.081075806054287
# Residual: 30.551189634774346
# Residual: 11.885209914878942
# Residual: 33.62728876527399
# Residual: 9.776544049207587
# Residual: 24.514973058598116
# Residual: 9.944776537129655
# Residual: 27.30304470367264
# Residual: 8.313587937213015
# Residual: 21.6810627769446
# Residual: 8.276135385967791
# Residual: 16.72763559478335
# Residual: 4.845597947307397
# Residual: 13.95925021142466
# Residual: 5.457946056732908
# Residual: 14.0707895149244
# Residual: 3.954543874016963
# Residual: 11.146150321816094
# Residual: 4.532733986037783
# Residual: 12.058832544775214
# Residual: 3.2028251570882276
# Residual: 9.094237620243803
# Residual: 3.8844775640172884
# Residual: 6.879907419672236
# Residual: 2.3870359154534526
# Residual: 6.343595903425012
# Residual: 2.067619744804688
# Residual: 5.699476961803157
# Residual: 1.9569247812614776
# Residual: 5.154239720199257
# Residual: 1.6966671397094615
# Residual: 4.981141852214932
# Residual: 1.6668883033562452
# Residual: 4.118556833534967
# Residual: 1.3914961632690392
# Residual: 2.9577454864047468
# Residual: 1.0026934902998619
# Residual: 2.7456134516978636
# Residual: 0.8486095917760395
# Residual: 2.4217211774084717
# Residual: 0.8454243985470384
# Residual: 2.244235500751529
# Residual: 0.7270482162712142
# Residual: 2.13958794035716
# Residual: 0.7154119969345629
# Residual: 1.8241768786683679
# Residual: 0.6031845916295424
# Residual: 1.2750573325902224
# Residual: 0.4333985660923645
# Residual: 1.1767142390017398
# Residual: 0.3891945463838056
# Residual: 1.0738615202717483
# Residual: 0.3657457063673064
# Residual: 0.9357287100283429
# Residual: 0.31130639440380037
# Residual: 0.9172284853993915
# Residual: 0.30725187226198614
# Residual: 0.828160151548218
# Residual: 0.2610027734772302
# Residual: 0.5488010231638327
# Residual: 0.18784867116482928
# Residual: 0.5046093778801151
# Residual: 0.1657435647211969
# Residual: 0.4629265911062248
# Residual: 0.1585776352440007
# Residual: 0.40207913069752976
# Residual: 0.13296001305570826
# Residual: 0.3925638871733099
# Residual: 0.13229793158825487
# Residual: 0.3330110356910154
# Residual: 0.11249932070495561
# Residual: 0.23597960371989757
# Residual: 0.08189160277834162
# Residual: 0.21666670037666336
# Residual: 0.07014099834486842
# Residual: 0.19914195622550324
# Residual: 0.0691477379295975
# Residual: 0.17323879286414012
# Residual: 0.05641031177947298
# Residual: 0.16750244674040005
# Residual: 0.057347836904227734
# Residual: 0.14523366751382127
# Residual: 0.048066073446534574
# Residual: 0.1011403277516365
# Residual: 0.0361336205387488
# Residual: 0.09340212307870388
# Residual: 0.029255217872560024
# Residual: 0.08524779637809843
# Residual: 0.030548854498192668
# Residual: 0.08416748751187697
# Residual: 0.021969005523715168
# Residual: 0.060942388721741736
# Residual: 0.027072136756032705
# Residual: 0.06099572411039844
# Residual: 0.02080062439199537
# Residual: 0.045977669302374125
# Residual: 0.01560579816577956
# Residual: 0.04637012421153486
# Residual: 0.011319109529722482
# Residual: 0.029663678025826812
# Residual: 0.01452549360692501
# Residual: 0.03249925572890788
# Residual: 0.01217928878031671
# Residual: 0.030201204412151128
# Residual: 0.00892645277781412
# Residual: 0.024459255975671113
# Residual: 0.00948565435828641
# Residual: 0.021983749407809228
# Residual: 0.006208411243278533
# Residual: 0.016441105748526752
# Residual: 0.0067838437971659005
# Residual: 0.016253078414592892
# Residual: 0.005071197112556547
# Residual: 0.013801442692056298
# Residual: 0.005038971547037363
# Residual: 0.012813171197194606
# Residual: 0.0039109475910663605
# Residual: 0.010733894479926676
# Residual: 0.004011366167105734
# Residual: 0.009294486488215625
# Residual: 0.0027642615023069084
# Residual: 0.007286836858838797
# Residual: 0.002834599232301116
# Residual: 0.007155088125728071
# Residual: 0.0020146260503679514
# Residual: 0.0057765195379033685
# Residual: 0.0023350988049060106
# Residual: 0.005419420718681067
# Residual: 0.0016536697512492537
# Residual: 0.004728739382699132
# Residual: 0.0017510258476249874
# Residual: 0.003851056972052902
# Residual: 0.0011631848174147308
# Residual: 0.003318781382404268
# Residual: 0.0012435007374733686
# Residual: 0.003212018113117665
# Residual: 0.0009483195026405156
# Residual: 0.002322885557077825
# Residual: 0.0009302478283643723
# Optimization terminated successfully.
#          Current function value: 0.000930
#          Iterations: 179
#          Function evaluations: 355
#  final_simplex: (array([[9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264069e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264068e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264067e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264070e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264067e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264070e+02,
#         1.69105286e+03]]), array([0.00093025, 0.00094832, 0.00116318, 0.0012435 , 0.00165367,
#        0.00175103]))
#            fun: 0.0009302478283643723
#        message: 'Optimization terminated successfully.'
#           nfev: 355
#            nit: 179
#         status: 0
#        success: True
#              x: array([9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264069e+02,
#        1.69105286e+03])

# %% [markdown]
# ## Finally, build a detector based on the fitted parameters

# %%
### poni1 is the y-coordinate (in meters) on the detector where the beam hits.
### poni2 is same for x. So we take the fitted beam center in pixels and multiply by the pixel size
poni1 = det_params.x[0] * det_pix[0]
poni2 = det_params.x[1] * det_pix[1]
sdd = det_params.x[2]

# Orientations and Angles
sample_orientation = 1    # 1 is horizontal, 2 is vertical
tilt_angle = 0            # tilt angle of sample in deg (misalignment in "chi")

# %% [markdown]
# ### show the master table again

# %%
df.loc[df['sample']=='Tol_fast_ng'].loc[df['theta']==0.14].loc[df['phi']>80]
# Out:
#                                                  tiff       sample solvent  \
# 30  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_38_...  Tol_fast_ng     Tol
# 31  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_39_...  Tol_fast_ng     Tol
# 33  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_40_...  Tol_fast_ng     Tol
# 34  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_42_...  Tol_fast_ng     Tol
# 35  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_44_...  Tol_fast_ng     Tol
# 36  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_46_...  Tol_fast_ng     Tol
# 37  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_47_...  Tol_fast_ng     Tol
# 38  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_48_...  Tol_fast_ng     Tol
# 39  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_49_...  Tol_fast_ng     Tol
# 41  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_50_...  Tol_fast_ng     Tol
# 42  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_51_...  Tol_fast_ng     Tol
# 43  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_52_...  Tol_fast_ng     Tol
# 44  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_53_...  Tol_fast_ng     Tol
# 45  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_54_...  Tol_fast_ng     Tol
# 46  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_55_...  Tol_fast_ng     Tol
# 47  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_56_...  Tol_fast_ng     Tol
# 48  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_57_...  Tol_fast_ng     Tol
# 49  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_58_...  Tol_fast_ng     Tol
# 50  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_59_...  Tol_fast_ng     Tol
# 52  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_60_...  Tol_fast_ng     Tol
# 53  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_62_...  Tol_fast_ng     Tol
# 54  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_63_...  Tol_fast_ng     Tol
# 55  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_64_...  Tol_fast_ng     Tol
# 56  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_65_...  Tol_fast_ng     Tol
# 57  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_66_...  Tol_fast_ng     Tol
# 58  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_67_...  Tol_fast_ng     Tol
# 59  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_69_...  Tol_fast_ng     Tol
# 61  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_70_...  Tol_fast_ng     Tol
# 62  /Users/nils/CC/N2200/data/nsls/Tol_fast_ng_71_...  Tol_fast_ng     Tol
#
#    speed grooves shot  theta      phi  exp_time   stamp
# 30  fast      ng   38   0.14   81.004      15.0  323640
# 31  fast      ng   39   0.14   84.005      15.0  323641
# 33  fast      ng   40   0.14   87.005      15.0  323642
# 34  fast      ng   42   0.14   93.005      15.0  323644
# 35  fast      ng   44   0.14   99.005      15.0  323646
# 36  fast      ng   46   0.14  105.005      15.0  323648
# 37  fast      ng   47   0.14  108.006      15.0  323649
# 38  fast      ng   48   0.14  111.006      15.0  323650
# 39  fast      ng   49   0.14  114.006      15.0  323651
# 41  fast      ng   50   0.14  117.006      15.0  323652
# 42  fast      ng   51   0.14  120.006      15.0  323653
# 43  fast      ng   52   0.14  123.006      15.0  323654
# 44  fast      ng   53   0.14  126.007      15.0  323655
# 45  fast      ng   54   0.14  129.007      15.0  323656
# 46  fast      ng   55   0.14  132.007      15.0  323657
# 47  fast      ng   56   0.14  135.007      15.0  323658
# 48  fast      ng   57   0.14  138.007      15.0  323659
# 49  fast      ng   58   0.14  141.007      15.0  323660
# 50  fast      ng   59   0.14  144.007      15.0  323661
# 52  fast      ng   60   0.14  147.008      15.0  323662
# 53  fast      ng   62   0.14  153.008      15.0  323664
# 54  fast      ng   63   0.14  156.008      15.0  323665
# 55  fast      ng   64   0.14  159.008      15.0  323666
# 56  fast      ng   65   0.14  162.008      15.0  323667
# 57  fast      ng   66   0.14  165.009      15.0  323668
# 58  fast      ng   67   0.14  168.009      15.0  323669
# 59  fast      ng   69   0.14  174.009      15.0  323671
# 61  fast      ng   70   0.14  177.009      15.0  323672
# 62  fast      ng   71   0.14  180.009      15.0  323673

# %% [markdown]
# ## Check out the raw data to see what we gotta do

# %%
def get_data(df, sample, det_shape=(1042,1042), offset=997):
    
    # Function to automatically load, reshape, offset, and median filter raw .tiff data
    
    data = fabio.open(df['tiff'].loc[sample]).data.reshape(det_shape) - offset
    return np.clip(medfilt(data),0,None)

# %%
test = get_data(df,2, offset=0)
corr_test = test-np.min(test)+1
log_test = np.log(corr_test)
tlim = np.percentile(log_test, (2, 99.6))

plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
plt.imshow(log_test, cmap='terrain',
           vmin=tlim[0], vmax=tlim[1])
plt.subplot(1,2,2)
hh=plt.hist(test[(test<1080) & (test>990)].ravel(), bins=50)
# Out:
# WARNING:fabio.TiffIO:Bogus StripByteCounts information
# <img src="data:image/png;base64,..." width="768">

# %% [markdown]
# ### Figure out these rotator angles...

# %%
### detector rotations from sample view
rot1 = 0    /180 * np.pi # move detector to right, in-plane angle# in radians
rot2 = 0    /180 * np.pi # move detector down, out-of-plane angle
rot3 = -88.8    /180 * np.pi # clockwise rotation

# %%
sample = 35

pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = df['theta'].loc[sample], tilt_angle = tilt_angle,
                     detector=detector)

imgt, qxy, qz = pg.transform_reciprocal(get_data(df,sample), method='lut', correctSolidAngle=True, unit='A')
corrimg = imgt-np.min(imgt)+1
logimg = np.log(corrimg)

clim = np.percentile(logimg[logimg>0], (3, 99.8))
plt.figure(figsize=(5,5))
ppl.implot(logimg, qxy, qz, mode='rsma',
           cmap="terrain", clim=clim,
           xlim=(-2,0.1), ylim=(-0.1,2),
           newfig=False)
# Out:
# WARNING:fabio.TiffIO:Bogus StripByteCounts information
# <img src="data:image/png;base64,..." width="480">
# /anaconda/envs/pygix/lib/python3.6/site-packages/pygix-0.1.4a0-py3.6.egg/pygix/plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':
# (<matplotlib.image.AxesImage at 0x101e6e550>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x101e58390>)

# %% [markdown]
# ## Define a function to make a transform with these parameters

# %%
print(det_params)
# Out:
#  final_simplex: (array([[9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264069e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264068e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264067e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264070e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264067e+02,
#         1.69105286e+03],
#        [9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264070e+02,
#         1.69105286e+03]]), array([0.00093025, 0.00094832, 0.00116318, 0.0012435 , 0.00165367,
#        0.00175103]))
#            fun: 0.0009302478283643723
#        message: 'Optimization terminated successfully.'
#           nfev: 355
#            nit: 179
#         status: 0
#        success: True
#              x: array([9.71575373e+02, 1.05340862e+01, 2.34227789e-01, 2.05264069e+02,
#        1.69105286e+03])

# %%
def setup_detector(theta):
    
    # NSLS-II is a photon Science CCD
 
    # 1042x1042 with 0.1017 mm pixels
    # 11 keV
    # nominally 228.8 mm
    # has ~ 16 degree horizontal tilt
    # has a ~ 995 count offset

    ### Starting beam position
    sdd = 0.23423
    center = [971.575, 10.534] # -y, +x

    ### Detector pixel size
    det_pix = [101.7e-6, 101.7e-6]
    detector = pyFAI.detectors.Detector(det_pix[0], det_pix[1])

    ### Wavelength
    wl = 1.127e-10

    ### Beamcenter from sample view in meters from lower left of detector
    poni1 = center[0] * det_pix[0]; poni2 = center[1] * det_pix[1]

    ### detector rotations from sample view
    rot1 = 0.0 /180 * np.pi # move detector to right, in-plane angle# in radians
    rot2 = 0.0 /180 * np.pi # move detector down, out-of-plane angle
    rot3 = -88.8 /180 * np.pi # clockwise rotation

    ### Orientations and Angles
    sample_orientation = 1    # 1 is horizontal, 2 is vertical
    tilt_angle = 0            # tilt angle of sample in deg (misalignment in "chi")
    
    ### Initialize the transform
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = theta, tilt_angle = tilt_angle,
                     detector=detector)
    
    return pg
