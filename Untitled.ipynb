# %%
# !pwd
# Out:
# /Users/nils/CC/in-situ-demo

# %%
from pathlib import Path

# %%
# !pwd
# Out:
# /Users/nils/CC/in-situ-demo

# %%
# !ls data
# Out:
# ALS      CHESS    NSLS-II  UV       examples

# %%
p = Path('data')
list(p.glob('**/*'))
# Out:
# [PosixPath('data/.DS_Store'),
#  PosixPath('data/ALS'),
#  PosixPath('data/CHESS'),
#  PosixPath('data/examples'),
#  PosixPath('data/NSLS-II'),
#  PosixPath('data/UV'),
#  PosixPath('data/ALS/.DS_Store'),
#  PosixPath('data/ALS/n2pa_run1'),
#  PosixPath('data/ALS/WLI'),
#  PosixPath('data/ALS/n2pa_run1/beamstop_test_180521013018704_2m.edf'),
#  PosixPath('data/ALS/n2pa_run1/beamstop_test_180521013018704_2m.txt'),
#  PosixPath('data/ALS/n2pa_run1/beamstop_test_180521014739069_2m.edf'),
#  PosixPath('data/ALS/n2pa_run1/beamstop_test_180521014739069_2m.txt'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p080_hi_2m.edf'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p080_hi_2m.txt'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p080_lo_2m.edf'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p080_lo_2m.txt'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p080_sfloat_2m.gb'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p100_hi_2m.edf'),
#  PosixPath('data/ALS/n2pa_run1/c_A0p100_hi_2m.txt'),
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame()
