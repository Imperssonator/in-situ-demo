# %% [markdown]
# # Pole Figures from ALS

# %% [markdown]
# ### Import python libraries

# %%
# numpy and plotting
import numpy as np
from scipy.signal import convolve2d, medfilt
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import rcParams

# Data handling
import os
import glob
import pandas as pd

# pyFAI
import pyFAI
from pyFAI.multi_geometry import MultiGeometry
from pyFAI.calibrant import get_calibrant
# from pyFAI.gui import jupyter

# pygix
import pygix
import fabio
from pygix import plotting as ppl

# Peak Fitting
from lmfit.models import GaussianModel, LorentzianModel, ExponentialModel, ConstantModel, LinearModel, VoigtModel

# Fix MPL params
rcParams.update({'figure.autolayout': True,
                 'xtick.top': True,
                 'xtick.direction': 'in',
                 'ytick.right': True,
                 'ytick.direction': 'in',
                 'font.sans-serif': 'Arial',
                 'font.size': 12
                })
mpl.rcParams['savefig.dpi'] = 300
mpl.rcParams['figure.dpi'] = 96
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %% [markdown]
# ## Load data files

# %%
base_folder = "\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl"
gb_glob = glob.glob(os.path.join(base_folder,'*.gb'))
edf_glob = glob.glob(os.path.join(base_folder,'*.edf'))
txt_glob = glob.glob(os.path.join(base_folder,'*.txt'))
gb_glob
# Out:
# ['\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p080_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p100_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p120_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p140_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p160_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p180_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p200_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p220_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p240_sfloat_2m.gb']

# %%
# %matplotlib notebook
im_shape = fabio.open(edf_glob[0]).data.shape
raw1 = np.fromfile(gb_glob[0], dtype=np.float32)
raw1 = raw1.reshape(im_shape)
clim = np.percentile(raw1, (2, 99.9))
plt.imshow(raw1, cmap='terrain', vmin=clim[0], vmax=clim[1])
# Out:
# <img src="data:image/png;base64,..." width="312">

# %% [markdown]
# ### Define pyFai detector parameters

# %%
def setup_detector(data):
    # Setup detector and transform
    ### Detector pixel size
    det_pix = [172e-6, 172e-6]
    detector = pyFAI.detectors.Detector(det_pix[0], det_pix[1])

    ### Wavelength
    wl = 1.23984e-10

    ### Center-pixel and sample-to-detector distance
    centerx =  304.831
    centery = 1244.7   # This is because I had to flip it upside-down
    sdd = 249.376e-3

    ### Beamcenter from sample view in meters from lower left of detector
    poni1 = centery * det_pix[1]; poni2 = centerx * det_pix[0]

    ### detector rotations from sample view
    rot1 = 0.0 /180 * np.pi # move detector to right, in-plane angle# in radians
    rot2 = 0.0 /180 * np.pi # move detector down, out-of-plane angle
    rot3 = 180 /180 * np.pi # clockwise rotation

    ### Orientations and Angles
    sample_orientation = 1    # 1 is horizontal, 2 is vertical
    incident_angle = 0.24   # indicent angle in deg
    tilt_angle = 0            # tilt angle of sample in deg (misalignment in "chi")
    
    ### Initialize the transform
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                     rot1 = rot1, rot2 = rot2, rot3 = rot3,
                     wavelength = wl, sample_orientation = sample_orientation,
                     incident_angle = incident_angle, tilt_angle = tilt_angle,
                     detector=detector)
    
    return pg

# %%
def show_sample_file(filename, prctile=(2,99.5), newfig=True):
    
    # Inputs:
    # filename: path to tiff file you want to see
    # prctile: the percentiles of image intensity where you want the lower and upper bounds on the color scale
    # set newfig to false if you're using this as part of a subplot
    
    raw = np.fromfile(gb_glob[0], dtype=np.float32).reshape(im_shape)
    
    # setup_detector defines a transform with the parameters I got from calibration
    pg = setup_detector(raw)
    
    # Generate the corrected image
    # get_raw loads the tif file and 3x3 median-filters it (de-zinger)
    imgt, qxy, qz = pg.transform_reciprocal(raw,
                                            method='lut',
                                            correctSolidAngle=True,
                                            unit='A')
    corr_img = imgt-np.min(imgt)+1
    log_img = np.log(corr_img)
    
    # Calculate where the color scale should be bounded
    clim = np.percentile(log_img[log_img>0], prctile)
    
    if newfig:
        plt.figure(figsize=(5,5))
    
    # pygix built-in plotting with nice formatting
    ppl.implot(log_img, qxy, qz, mode='rsma',
               cmap="terrain", clim=clim,
               xlim=(-1,1), ylim=(-0.1,1),
               newfig=False)
    
    return raw, imgt

# %%
plt.figure(figsize=(10,5))
raw, transformed = show_sample_file(gb_glob[0], newfig=False, prctile=(60,99.99))
plt.savefig('benzyl_example.png')
# Out:
# <img src="data:image/png;base64,..." width="960">
# typ: center
# unit: q_A^-1
# typ: delta
# unit: q_A^-1
# pos0 shape: (1679, 1475)
# dpos0 shape: (1679, 1475)
# pos1 shape: (1679, 1475)
# dpos1 shape: (1679, 1475)
# npt: (1475, 1679)
# pos0Range: (-0.14877706887636064, 0.3374524180991339)
# pos1Range: (-0.14517423783795752, 0.33053662481932206)
# mask: None
# mask_checksum: None
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':

# %%
transformed.shape
# Out:
# (1679, 1475)

# %%
raw = np.fromfile(gb_glob[0], dtype=np.float32).reshape(im_shape)
pg = setup_detector(raw)

intensity, q_abs, chi = pg.transform_polar(raw, unit='A',
                                           npt=(180, 180),
                                           chi_range=(-220,-160), q_range=(0,2),
                                           correctSolidAngle=True,
                                           method='lut')

vmin, vmax = np.percentile(intensity, (1,99))

plt.figure(figsize=(5,5))
plt.imshow(intensity, cmap='terrain',
           vmin=vmin, vmax=vmax,
           extent = [q_abs.min(), q_abs.max(), chi.min(), chi.max()],
           aspect='auto')
plt.xlabel(r'$q_{xy} \: (\AA^{-1})$')
plt.ylabel(r'$\chi \: (deg.)$')
# plt.savefig('benzyl_q_chi_example.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3de6066d2aba> in <module>()
# ----> 1 raw = np.fromfile(gb_glob[0], dtype=np.float32).reshape(im_shape)
#       2 pg = setup_detector(raw)
#       3
#       4 intensity, q_abs, chi = pg.transform_polar(raw, unit='A',
#       5                                            npt=(180, 180),
#
# NameError: name 'np' is not defined

# %%
qb = (0.275, 0.345)
q_pix = np.array([np.where(q_abs>qb[0])[0][0], np.where(q_abs>qb[1])[0][0]])
qbg = qb + np.array([-1, 1])*0.03
q_bg_pix = np.array([np.where(q_abs>qbg[0])[0][0], np.where(q_abs>qbg[1])[0][0]])


print(q_pix)
print(q_bg_pix)


cut = intensity[:,q_pix[0]:q_pix[1]].sum(axis=1)/np.diff(q_pix) - np.mean(intensity[:,q_bg_pix], axis=1)

plt.figure(figsize=(5,5))
plt.plot(chi,cut * np.abs(np.sin(chi * np.pi / 180)))
plt.xlabel('chi (deg.)')
plt.ylabel('peak integral')
# Out:
# [41 52]
# [37 56]
# <img src="data:image/png;base64,..." width="480">
# Text(0,0.5,'peak integral')

# %%
fig, axes = plt.subplots(3,3, figsize=(10,10))

for i, file in enumerate(gb_glob):
    
    raw = np.fromfile(gb_glob[i], dtype=np.float32).reshape(im_shape)
    pg = setup_detector(raw)

    intensity, q_abs, chi = pg.transform_polar(raw, unit='A',
                                               npt=(180, 180),
                                               chi_range=(-90,90), q_range=(0,1.2),
                                               correctSolidAngle=True,
                                               method='splitpix')

    vmin, vmax = np.percentile(intensity, (1,99))
    
    plt.subplot(3,3,i+1)
    plt.imshow(intensity, cmap='terrain',
               vmin=vmin, vmax=vmax,
               extent = [q_abs.min(), q_abs.max(), chi.min(), chi.max()],
               aspect='auto')
    plt.xlabel(r'$q_{xy} \: (\AA^{-1})$')
    plt.ylabel(r'$\chi \: (deg.)$')
    plt.title(os.path.basename(file).split('_')[1])
    
plt.savefig('benzyl_q_chi_grid.png')
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
gb_glob
# Out:
# ['\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p080_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p100_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p120_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p140_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p160_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p180_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p200_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p220_sfloat_2m.gb',
#  '\\\\cfs2e.nist.gov\\63_mml\\642\\users\\saxs8542\\Data\\ALS 7.3.3\\2018_May\\WAXS\\EPFL\\benzyl\\benzyl_A0p240_sfloat_2m.gb']

# %%
fig, axes = plt.subplots(3,3, figsize=(10,10))

for i, file in enumerate(gb_glob):
    
    raw = np.fromfile(gb_glob[i], dtype=np.float32).reshape(im_shape)
    pg = setup_detector(raw)

    intensity, q_abs, chi = pg.transform_polar(raw, unit='A',
                                               npt=(180, 180),
                                               chi_range=(-90,90), q_range=(0,1.2),
                                               correctSolidAngle=True,
                                               method='splitpix')

    vmin, vmax = np.percentile(intensity, (1,99))
    
    plt.subplot(3,3,i+1)
    
    qb = (0.275, 0.345)
    q_pix = np.array([np.where(q_abs>qb[0])[0][0], np.where(q_abs>qb[1])[0][0]])
    qbg = qb + np.array([-1, 1])*0.03
    q_bg_pix = np.array([np.where(q_abs>qbg[0])[0][0], np.where(q_abs>qbg[1])[0][0]])
    
    cut = intensity[:,q_pix[0]:q_pix[1]].sum(axis=1)/np.diff(q_pix) - np.mean(intensity[:,q_bg_pix], axis=1)

    plt.plot(chi,cut * np.abs(np.sin(chi * np.pi / 180)))
    plt.xlabel(r'$\chi \: (deg.)$')
    plt.ylabel("Peak Integral")
    plt.title(os.path.basename(file).split('_')[1])
    
plt.savefig('benzyl_poles_grid.png')
# Out:
# <img src="data:image/png;base64,..." width="960">

# %%
chi
# Out:
# array([-99.44444435, -98.33333324, -97.22222213, -96.11111102,
#        -94.99999991, -93.8888888 , -92.77777769, -91.66666658,
#        -90.55555547, -89.44444436, -88.33333325, -87.22222214,
#        -86.11111103, -84.99999992, -83.88888881, -82.7777777 ,
#        -81.66666659, -80.55555548, -79.44444437, -78.33333326,
#        -77.22222215, -76.11111104, -74.99999993, -73.88888882,
#        -72.77777771, -71.6666666 , -70.55555549, -69.44444438,
#        -68.33333327, -67.22222216, -66.11111105, -64.99999994,
#        -63.88888883, -62.77777772, -61.66666661, -60.5555555 ,
#        -59.44444439, -58.33333328, -57.22222217, -56.11111106,
#        -54.99999995, -53.88888884, -52.77777773, -51.66666662,
#        -50.55555551, -49.4444444 , -48.33333329, -47.22222218,
#        -46.11111107, -44.99999996, -43.88888885, -42.77777774,
#        -41.66666663, -40.55555552, -39.44444441, -38.3333333 ,
#        -37.22222219, -36.11111108, -34.99999997, -33.88888886,
#        -32.77777775, -31.66666664, -30.55555553, -29.44444442,
#        -28.33333331, -27.2222222 , -26.11111109, -24.99999998,
#        -23.88888887, -22.77777776, -21.66666665, -20.55555554,
#        -19.44444443, -18.33333332, -17.22222221, -16.1111111 ,
#        -14.99999999, -13.88888888, -12.77777777, -11.66666666,
#        -10.55555555,  -9.44444444,  -8.33333333,  -7.22222222,
#         -6.11111111,  -5.        ,  -3.88888889,  -2.77777778,
#         -1.66666667,  -0.55555556,   0.55555556,   1.66666667,
#          2.77777778,   3.88888889,   5.        ,   6.11111111,
#          7.22222222,   8.33333333,   9.44444444,  10.55555555,
#         11.66666666,  12.77777777,  13.88888888,  14.99999999,
#         16.1111111 ,  17.22222221,  18.33333332,  19.44444443,
#         20.55555554,  21.66666665,  22.77777776,  23.88888887,
#         24.99999998,  26.11111109,  27.2222222 ,  28.33333331,
#         29.44444442,  30.55555553,  31.66666664,  32.77777775,
#         33.88888886,  34.99999997,  36.11111108,  37.22222219,
#         38.3333333 ,  39.44444441,  40.55555552,  41.66666663,
#         42.77777774,  43.88888885,  44.99999996,  46.11111107,
#         47.22222218,  48.33333329,  49.4444444 ,  50.55555551,
#         51.66666662,  52.77777773,  53.88888884,  54.99999995,
#         56.11111106,  57.22222217,  58.33333328,  59.44444439,
#         60.5555555 ,  61.66666661,  62.77777772,  63.88888883,
#         64.99999994,  66.11111105,  67.22222216,  68.33333327,
#         69.44444438,  70.55555549,  71.6666666 ,  72.77777771,
#         73.88888882,  74.99999993,  76.11111104,  77.22222215,
#         78.33333326,  79.44444437,  80.55555548,  81.66666659,
#         82.7777777 ,  83.88888881,  84.99999992,  86.11111103,
#         87.22222214,  88.33333325,  89.44444436,  90.55555547,
#         91.66666658,  92.77777769,  93.8888888 ,  94.99999991,
#         96.11111102,  97.22222213,  98.33333324,  99.44444435])

# %% [markdown]
# ### Define a function to get the data for a row

# %%
def save_data(df_row, generate=False):
    
    base_path = os.path.splitext(df_row['fullpath'])[0]
    data_path = base_path+'_data.npy'
    dark_path = base_path+'_dark.npy'
    log_path = base_path+'_logimg.npy'
    
    if generate:
        data = fabio.open(df_row['fullpath']).data
        data = np.flipud(data)
        dark = np.flipud(fabio.open(df_row['darkfile']).data)

        pg = setup_detector(data, df_row['theta'])
        imgt, qxy, qz = pg.transform_reciprocal(data,
                                                method='lut',
                                                correctSolidAngle=True,
                                                unit='A',
                                                dark=dark)
        corrimg = imgt-np.min(imgt)+1
        logimg = np.log(corrimg)

        np.save(data_path, data)
        np.save(dark_path, dark)
        np.save(log_path, logimg)
    
    return data_path, dark_path, log_path

def get_data(df_row):
    data = np.load(df_row.datapath)
    dark = np.load(df_row.darkpath)
    logdata = np.load(df_row.logpath)
    
    return data, dark, logdata

# %% [markdown]
# ### Parse file names and build master dataframe for results

# %%
def parse_filename(file):
    
    parts = file.split('_')
    parsed = pd.Series()
    
    parsed['solvent'] = parts[0]
    
    if 'spin' in parts:
        parsed['speed'] = 'spin'
        parsed['grooves'] = 'none'
        parsed['sample_phi'] = 'none'
    
    else:
        parsed['speed'] = parts[1]
        parsed['grooves'] = parts[2]
        parsed['sample_phi'] = parts[3]
        
    if 'ang' in parts:
        parsed['theta'] = float(parts[-1][-5]) * 0.02 + 0.06
        parsed['exp_time'] = 30
        
    else:
        parsed['theta'] = 0.12
        parsed['exp_time'] = 90
        
    return parsed

# %%
df_master = pd.DataFrame()

df_master['fullpath'] = pd.Series(globby)
df_master['filename'] = pd.Series([s[-1] for s in df_master['fullpath'].str.split('\\')])
df_master = pd.concat([df_master, df_master['filename'].apply(parse_filename)],
                      axis=1)
df_master['darkfile'] = df_master['exp_time'].apply(lambda t: dark30file if t==30
                                                else dark90file)

df_master['samplename']=['_'.join(s[:4]) for s in df_master['filename'].str.split('_')]
df_master['specnum'] = [int(s[-1].strip('.tif')) for s in df_master['filename'].str.split('_')]
df_master['sample_phi'] = df_master['sample_phi'].str.replace('90b','0')

print('file names parsed')

# Comment this line out if you've already done
df_master['datapath'], df_master['darkpath'], df_master['logpath'] = \
    zip(*df_master.apply(save_data, axis=1))

df_master
# Out:
# file names parsed
#                                               fullpath  \
# 0    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 1    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 2    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 3    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 4    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 5    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 6    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 7    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 8    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 9    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 10   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 11   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 12   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 13   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 14   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 15   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 16   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 17   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 18   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 19   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 20   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 21   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 22   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 23   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 24   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 25   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 26   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 27   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 28   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# 29   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# ..                                                 ...
# 165  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 166  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 167  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 168  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 169  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 170  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 171  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 172  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 173  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 174  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 175  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 176  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 177  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 178  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 179  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 180  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 181  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 182  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 183  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 184  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 185  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 186  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 187  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 188  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 189  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 190  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 191  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 192  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 193  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
# 194  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
#
#                                  filename solvent speed grooves sample_phi  \
# 0          cb_hi_nogr_0_01190534_0001.tif      cb    hi    nogr          0
# 1          cb_hi_nogr_0_01190534_0002.tif      cb    hi    nogr          0
# 2      cb_hi_nogr_0_ang_01190531_0001.tif      cb    hi    nogr          0
# 3      cb_hi_nogr_0_ang_01190531_0002.tif      cb    hi    nogr          0
# 4      cb_hi_nogr_0_ang_01190531_0003.tif      cb    hi    nogr          0
# 5      cb_hi_nogr_0_ang_01190531_0004.tif      cb    hi    nogr          0
# 6      cb_hi_nogr_0_ang_01190531_0005.tif      cb    hi    nogr          0
# 7         cb_hi_nogr_90_01190525_0001.tif      cb    hi    nogr         90
# 8         cb_hi_nogr_90_01190525_0002.tif      cb    hi    nogr         90
# 9     cb_hi_nogr_90_ang_01190521_0001.tif      cb    hi    nogr         90
# 10    cb_hi_nogr_90_ang_01190521_0002.tif      cb    hi    nogr         90
# 11    cb_hi_nogr_90_ang_01190521_0003.tif      cb    hi    nogr         90
# 12    cb_hi_nogr_90_ang_01190521_0004.tif      cb    hi    nogr         90
# 13    cb_hi_nogr_90_ang_01190521_0005.tif      cb    hi    nogr         90
# 14      cb_hi_par_0_ang_01171357_0001.tif      cb    hi     par          0
# 15      cb_hi_par_0_ang_01171357_0002.tif      cb    hi     par          0
# 16      cb_hi_par_0_ang_01171357_0003.tif      cb    hi     par          0
# 17      cb_hi_par_0_ang_01171357_0004.tif      cb    hi     par          0
# 18      cb_hi_par_0_ang_01171357_0005.tif      cb    hi     par          0
# 19         cb_hi_par_0__01171400_0001.tif      cb    hi     par          0
# 20         cb_hi_par_0__01171400_0002.tif      cb    hi     par          0
# 21     cb_hi_par_90_ang_01171346_0001.tif      cb    hi     par         90
# 22     cb_hi_par_90_ang_01171346_0002.tif      cb    hi     par         90
# 23     cb_hi_par_90_ang_01171346_0003.tif      cb    hi     par         90
# 24     cb_hi_par_90_ang_01171346_0004.tif      cb    hi     par         90
# 25     cb_hi_par_90_ang_01171346_0005.tif      cb    hi     par         90
# 26        cb_hi_par_90__01171350_0001.tif      cb    hi     par         90
# 27        cb_hi_par_90__01171350_0002.tif      cb    hi     par         90
# 28     cb_hi_perp_0_ang_01171636_0001.tif      cb    hi    perp          0
# 29     cb_hi_perp_0_ang_01171636_0002.tif      cb    hi    perp          0
# ..                                    ...     ...   ...     ...        ...
# 165       tol_lo_par_0__01171524_0001.tif     tol    lo     par          0
# 166       tol_lo_par_0__01171524_0002.tif     tol    lo     par          0
# 167       tol_lo_par_90_01171510_0001.tif     tol    lo     par         90
# 168       tol_lo_par_90_01171510_0002.tif     tol    lo     par         90
# 169       tol_lo_par_90_01171510_0003.tif     tol    lo     par         90
# 170       tol_lo_par_90_01171510_0004.tif     tol    lo     par         90
# 171       tol_lo_par_90_01171510_0005.tif     tol    lo     par         90
# 172      tol_lo_par_90__01171513_0001.tif     tol    lo     par         90
# 173      tol_lo_par_90__01171513_0002.tif     tol    lo     par         90
# 174   tol_lo_perp_0_ang_01171255_0001.tif     tol    lo    perp          0
# 175   tol_lo_perp_0_ang_01171255_0002.tif     tol    lo    perp          0
# 176   tol_lo_perp_0_ang_01171255_0003.tif     tol    lo    perp          0
# 177   tol_lo_perp_0_ang_01171255_0004.tif     tol    lo    perp          0
# 178   tol_lo_perp_0_ang_01171255_0005.tif     tol    lo    perp          0
# 179      tol_lo_perp_0__01171259_0001.tif     tol    lo    perp          0
# 180      tol_lo_perp_0__01171259_0002.tif     tol    lo    perp          0
# 181  tol_lo_perp_90_ang_01171305_0001.tif     tol    lo    perp         90
# 182  tol_lo_perp_90_ang_01171305_0002.tif     tol    lo    perp         90
# 183  tol_lo_perp_90_ang_01171305_0003.tif     tol    lo    perp         90
# 184  tol_lo_perp_90_ang_01171305_0004.tif     tol    lo    perp         90
# 185  tol_lo_perp_90_ang_01171305_0005.tif     tol    lo    perp         90
# 186     tol_lo_perp_90__01171246_0001.tif     tol    lo    perp         90
# 187     tol_lo_perp_90__01171246_0002.tif     tol    lo    perp         90
# 188        tol_spin_ang_01171443_0001.tif     tol  spin    none       none
# 189        tol_spin_ang_01171443_0002.tif     tol  spin    none       none
# 190        tol_spin_ang_01171443_0003.tif     tol  spin    none       none
# 191        tol_spin_ang_01171443_0004.tif     tol  spin    none       none
# 192        tol_spin_ang_01171443_0005.tif     tol  spin    none       none
# 193           tol_spin__01171446_0001.tif     tol  spin    none       none
# 194           tol_spin__01171446_0002.tif     tol  spin    none       none
#
#      theta  exp_time                                           darkfile  \
# 0     0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 1     0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 2     0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 3     0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 4     0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 5     0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 6     0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 7     0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 8     0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 9     0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 10    0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 11    0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 12    0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 13    0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 14    0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 15    0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 16    0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 17    0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 18    0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 19    0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 20    0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 21    0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 22    0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 23    0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 24    0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 25    0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 26    0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 27    0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 28    0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 29    0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# ..     ...       ...                                                ...
# 165   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 166   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 167   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 168   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 169   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 170   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 171   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 172   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 173   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 174   0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 175   0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 176   0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 177   0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 178   0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 179   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 180   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 181   0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 182   0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 183   0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 184   0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 185   0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 186   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 187   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 188   0.08        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 189   0.10        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 190   0.12        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 191   0.14        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 192   0.16        30  F:\N2200 Project\data\ssrl\dark30_01190713_000...
# 193   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 194   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
#
#                 samplename  specnum  \
# 0             cb_hi_nogr_0        1
# 1             cb_hi_nogr_0        2
# 2             cb_hi_nogr_0        1
# 3             cb_hi_nogr_0        2
# 4             cb_hi_nogr_0        3
# 5             cb_hi_nogr_0        4
# 6             cb_hi_nogr_0        5
# 7            cb_hi_nogr_90        1
# 8            cb_hi_nogr_90        2
# 9            cb_hi_nogr_90        1
# 10           cb_hi_nogr_90        2
# 11           cb_hi_nogr_90        3
# 12           cb_hi_nogr_90        4
# 13           cb_hi_nogr_90        5
# 14             cb_hi_par_0        1
# 15             cb_hi_par_0        2
# 16             cb_hi_par_0        3
# 17             cb_hi_par_0        4
# 18             cb_hi_par_0        5
# 19             cb_hi_par_0        1
# 20             cb_hi_par_0        2
# 21            cb_hi_par_90        1
# 22            cb_hi_par_90        2
# 23            cb_hi_par_90        3
# 24            cb_hi_par_90        4
# 25            cb_hi_par_90        5
# 26            cb_hi_par_90        1
# 27            cb_hi_par_90        2
# 28            cb_hi_perp_0        1
# 29            cb_hi_perp_0        2
# ..                     ...      ...
# 165           tol_lo_par_0        1
# 166           tol_lo_par_0        2
# 167          tol_lo_par_90        1
# 168          tol_lo_par_90        2
# 169          tol_lo_par_90        3
# 170          tol_lo_par_90        4
# 171          tol_lo_par_90        5
# 172          tol_lo_par_90        1
# 173          tol_lo_par_90        2
# 174          tol_lo_perp_0        1
# 175          tol_lo_perp_0        2
# 176          tol_lo_perp_0        3
# 177          tol_lo_perp_0        4
# 178          tol_lo_perp_0        5
# 179          tol_lo_perp_0        1
# 180          tol_lo_perp_0        2
# 181         tol_lo_perp_90        1
# 182         tol_lo_perp_90        2
# 183         tol_lo_perp_90        3
# 184         tol_lo_perp_90        4
# 185         tol_lo_perp_90        5
# 186         tol_lo_perp_90        1
# 187         tol_lo_perp_90        2
# 188  tol_spin_ang_01171443        1
# 189  tol_spin_ang_01171443        2
# 190  tol_spin_ang_01171443        3
# 191  tol_spin_ang_01171443        4
# 192  tol_spin_ang_01171443        5
# 193     tol_spin__01171446        1
# 194     tol_spin__01171446        2
#
#                                               datapath  \
# 0    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 1    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 2    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 3    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 4    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 5    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 6    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 7    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 8    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 9    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 10   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 11   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 12   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 13   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 14   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 15   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 16   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 17   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 18   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 19   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 20   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 21   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 22   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 23   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 24   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 25   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 26   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 27   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 28   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# 29   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# ..                                                 ...
# 165  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 166  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 167  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 168  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 169  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 170  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 171  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 172  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 173  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 174  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 175  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 176  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 177  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 178  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 179  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 180  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 181  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 182  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 183  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 184  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 185  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 186  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 187  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 188  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 189  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 190  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 191  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 192  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 193  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
# 194  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
#
#                                               darkpath  \
# 0    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 1    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 2    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 3    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 4    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 5    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 6    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 7    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 8    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 9    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 10   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 11   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 12   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 13   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 14   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 15   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 16   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 17   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 18   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 19   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 20   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 21   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 22   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 23   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 24   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 25   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 26   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 27   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 28   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# 29   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# ..                                                 ...
# 165  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 166  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 167  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 168  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 169  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 170  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 171  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 172  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 173  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 174  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 175  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 176  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 177  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 178  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 179  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 180  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 181  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 182  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 183  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 184  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 185  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 186  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 187  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 188  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 189  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 190  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 191  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 192  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 193  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
# 194  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
#
#                                                logpath
# 0    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 1    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# 2    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 3    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 4    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 5    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 6    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_a...
# 7    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 8    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 9    F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 10   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 11   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 12   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 13   F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_90_...
# 14   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 15   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 16   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 17   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 18   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0_an...
# 19   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 20   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_0__0...
# 21   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 22   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 23   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 24   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 25   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90_a...
# 26   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 27   F:\N2200 Project\data\ssrl\waxs\cb_hi_par_90__...
# 28   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# 29   F:\N2200 Project\data\ssrl\waxs\cb_hi_perp_0_a...
# ..                                                 ...
# 165  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 166  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_0__...
# 167  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 168  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 169  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 170  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 171  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 172  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 173  F:\N2200 Project\data\ssrl\waxs\tol_lo_par_90_...
# 174  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 175  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 176  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 177  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 178  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 179  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 180  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_0_...
# 181  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 182  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 183  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 184  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 185  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 186  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 187  F:\N2200 Project\data\ssrl\waxs\tol_lo_perp_90...
# 188  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 189  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 190  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 191  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 192  F:\N2200 Project\data\ssrl\waxs\tol_spin_ang_0...
# 193  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
# 194  F:\N2200 Project\data\ssrl\waxs\tol_spin__0117...
#
# [195 rows x 14 columns]

# %% [markdown]
# ### Show raw detector data in log scale

# %% [markdown]
# ### Setup detector and sample geometry, Get qz-qxy data

# %%
def show_sample(sample, df_master, newfig=True):
    
    logimg = np.load(df_master['logpath'].loc[sample])
    clim = np.percentile(logimg[logimg>0], (0.5, 99.9))
    
    ppl.implot(logimg, qxy, qz,
               mode='rsma', cmap="terrain", clim=clim,
               xlim=(-.6,2), ylim=(-0.05,2), newfig=newfig)

# %%
# show_sample(0,df_master)

# %% [markdown]
# ### Define some peak fitting and plotting functions

# %%
def plot_peak_fits(x,y,df_peaks,out_dict):

    color_list = ['#3cb44b','#0082c8','#f58231','#911eb4','#800000','#000080','#808000']
    f1 = plt.figure()
    plt.semilogy(x, y, 'r-')
    
    for i in df_peaks['set'].unique():
        
        out = out_dict[i]
        df_set = df_peaks.loc[df_peaks.set==i]
        
        # Build bounded x and y vectors
        lb = df_set.iloc[0].lb
        ub = df_set.iloc[0].ub
        lb_ind = int(np.where(x>=lb)[0][0])
        ub_ind = int(np.where(x>=ub)[0][0])
        xb = x[lb_ind:ub_ind]
        yb = y[lb_ind:ub_ind]

        # Add peaks to plot
        comps = out.eval_components(x=xb)
        plt.semilogy(xb, out.eval(x=xb), '-', color = color_list[i])
        for c in comps:
            try:
                plt.semilogy(xb, comps[c], '--', color = color_list[i])
            except:
                const_eval = np.ones(xb.shape)*comps[c]
                plt.semilogy(xb, const_eval, '--', color = color_list[i])

    # Show the plot
    f1.axes[0].set_ylim( bottom=max(1,np.min(y)/10), top=np.max(y)*1.3 )
    plt.show()

# %%
def fit_sector_peaks(df_row,chi,df_peak_init,chi_width=4,radial_range=(1.35,20)):
    
    data, dark, _ = get_data(df_row)
    theta = df_row.theta
    df_new = df_peak_init.copy()
    
    # Get I vs Q for angle d
    y, x = pg.profile_sector(data, npt=1000, chi_pos=chi,
                                     chi_width=chi_width, radial_range=radial_range,
                                     correctSolidAngle=True,
                                     method='lut', dark=dark)
    
    out_dict = {}
    
    # Run peak fits for each set of peaks
    for i in df_new['set'].unique():
        
        df_peaks = df_new.loc[df_new.set==i]

        # Build bounded x and y vectors
        lb = df_peaks.iloc[0].lb
        ub = df_peaks.iloc[0].ub
        lb_ind = int(np.where(x>=lb)[0][0])
        ub_ind = int(np.where(x>=ub)[0][0])
        xb = x[lb_ind:ub_ind]
        yb = y[lb_ind:ub_ind]

        # Initialize Baseline model
        comp_mod = []

        if i not in [1,2]:
            lin_mod = ConstantModel(prefix='lin_')
            pars = lin_mod.make_params(c=yb.min())
            comp_mod.append(lin_mod)
        else:
            lin_mod = ExponentialModel(prefix='lin_')
            pars = lin_mod.guess(y,x=x)
            comp_mod.append(lin_mod)

        # Add peaks
        for index, peak in df_peaks.iterrows():
            prefix = peak['name']+'_'
            peak_temp  = VoigtModel(prefix=prefix)

            pars.update(peak_temp.make_params())
            pars[prefix+'center'].set(peak['cent'], min=peak['min'], max=peak['max'])
            pars[prefix+'sigma'].set(peak['sig'])
            pars[prefix+'amplitude'].set(peak['amp'], min=0)

            comp_mod.append(peak_temp)

        # Build composite model
        comp_mod = np.sum(comp_mod)
        out = comp_mod.fit(yb, pars, x=xb)
        params_dict=out.params.valuesdict()

        # Store peak features in original dataframe
        for peak, prop in [s.split('_') for s in list(params_dict.keys())]:
            df_new.loc[df_new.name==peak,prop] = params_dict[peak+'_'+prop]
        df_new['chi'] = chi
        out_dict[i] = out
        
    return df_new, out_dict, x, y

# %% [markdown]
# ### Get in-plane sector

# %%
data = np.load(df_master.iloc[0].datapath)
dark = np.load(df_master.iloc[0].darkpath)
pg = setup_detector(data, df_master.iloc[0].theta)
int_sect, q_sect = pg.profile_sector(data, npt=1000, chi_pos=86,
                                 chi_width=4, radial_range=(1.35, 20),
                                 correctSolidAngle=True,
                                 method='lut', dark=dark)
ppl.plot(q_sect,int_sect, logy=True)
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ### Run peak fits over sectors starting from 88 back to 5 deg.
# Initialize each fit from previous parameters

# %% [markdown]
# ### Perform composite peak fits

# %%
p100 = {'name': 'p100', 'set':1, 'cent': 2.3, 'min': 2.0, 'max': 3.0, 'sig': 0.1, 'amp': 1000, 'lb': 1.5, 'ub': 3.8}

p001 = {'name': 'p001', 'set':2, 'cent': 4.5, 'min': 4.0, 'max': 4.7, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}
p200 = {'name': 'p200', 'set':2, 'cent': 4.9, 'min': 4.7, 'max': 5.5, 'sig': 0.1, 'amp': 30, 'lb': 3.8, 'ub': 5.7}

p300 = {'name': 'p300', 'set':4, 'cent': 7.4, 'min': 7.0, 'max': 8.0, 'sig': 0.1, 'amp': 10, 'lb': 6.4, 'ub': 19.5}

p001a ={'name': 'p001a','set':4, 'cent': 8.8, 'min': 8.6, 'max': 9.0, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 19.5}
p002 = {'name': 'p002', 'set':4, 'cent': 9.5, 'min': 9.3, 'max': 9.8, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}
p400 = {'name': 'p400', 'set':4, 'cent': 9.9, 'min': 9.7, 'max': 10.3, 'sig': 0.1, 'amp': 10, 'lb': 8.4, 'ub': 11}

phalo ={'name': 'phalo', 'set':4, 'cent': 14, 'min': 12, 'max': 15, 'sig': 0.2, 'amp': 10, 'lb': 14, 'ub': 19.5}
p010 = {'name': 'p010', 'set':4, 'cent': 16.0, 'min': 15.2, 'max': 16.5, 'sig': 0.1, 'amp': 10, 'lb': 14, 'ub': 19.5}
p002a ={'name': 'p002a','set':4, 'cent': 17.7, 'min': 17.2, 'max': 18, 'sig': 0.1, 'amp': 10, 'lb': 14, 'ub': 19.5}

df_peak_init = pd.DataFrame.from_dict([p100,p001,p200,p300,p001a,p400,phalo,p010,p002a]) #p002
df_peak_init
# Out:
#     amp  cent    lb   max   min   name  set  sig    ub
# 0  1000   2.3   1.5   3.0   2.0   p100    1  0.1   3.8
# 1    30   4.5   3.8   4.7   4.0   p001    2  0.1   5.7
# 2    30   4.9   3.8   5.5   4.7   p200    2  0.1   5.7
# 3    10   7.4   6.4   8.0   7.0   p300    4  0.1  19.5
# 4    10   8.8   8.4   9.0   8.6  p001a    4  0.1  19.5
# 5    10   9.9   8.4  10.3   9.7   p400    4  0.1  11.0
# 6    10  14.0  14.0  15.0  12.0  phalo    4  0.2  19.5
# 7    10  16.0  14.0  16.5  15.2   p010    4  0.1  19.5
# 8    10  17.7  14.0  18.0  17.2  p002a    4  0.1  19.5

# %%
df_pex, out_dict_ex, x, y = fit_sector_peaks(df_master.loc[0],86,df_peak_init)
plot_peak_fits(x,y,df_pex,out_dict_ex)
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %% [markdown]
# ### Write a master function to automate analysis

# %%
def Hermans(ii, chi):
    sin_chi = np.sin(np.deg2rad(chi))
    cos2chi = np.cos(np.deg2rad(chi)) ** 2
    return np.sum(ii * cos2chi * sin_chi) / np.sum(ii * sin_chi)

def interp_nans(data):
    mask = np.isnan(data)
    data[mask] = np.interp(np.flatnonzero(mask), np.flatnonzero(~mask), data[~mask])
    return data

# %%
def analyze_n22(df_row, df_peak_init, chi_pos=86):
    
    data, dark, _ = get_data(df_row)
    pg = setup_detector(data,df_row.theta)
    df_res = df_row.copy()
    
    # Store results of peak fits in df_res
    df_pf, out_dict, _, _ = fit_sector_peaks(df_row,chi_pos,df_peak_init,chi_width=4,radial_range=(1.35,20))
    df_res['peak_fits'] = df_pf
    df_res['out_dict'] = out_dict
    
    # Get Herman's Orientation and store
    p100_q = df_pf.loc[df_pf['name']=='p100', 'center'].iloc[0]
    
    cake, chi = pg.profile_chi(data, npt=200,
                               radial_pos=p100_q, radial_width=.3,
                               chi_range=(3,86),
                               correctSolidAngle=True,
                               method='lut', dark=dark)
    
    df_res['Hermans'] = Hermans(interp_nans(cake),chi)
    
    return df_res

# %%
analyze_n22(df_master.loc[0],df_peak_init)
# Out:
# fullpath      F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# filename                         cb_hi_nogr_0_01190534_0001.tif
# solvent                                                      cb
# speed                                                        hi
# grooves                                                    nogr
# sample_phi                                                    0
# theta                                                      0.12
# exp_time                                                     90
# darkfile      F:\N2200 Project\data\ssrl\dark90_01190715_000...
# samplename                                         cb_hi_nogr_0
# specnum                                                       1
# datapath      F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# darkpath      F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# logpath       F:\N2200 Project\data\ssrl\waxs\cb_hi_nogr_0_0...
# peak_fits         amp  cent    lb   max   min   name  set  s...
# out_dict      {1: <lmfit.model.ModelResult object at 0x00000...
# Hermans                                                0.202242
# Name: 0, dtype: object

# %%
df_res = pd.DataFrame()
df_analysis = df_master.loc[[94,101,108,122,129,131,138,145]]
df_analysis
# Out:
#                                               fullpath  \
# 94   F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_0_...
# 101  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 108  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 122  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_0__...
# 129  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 131  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 138  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_0_...
# 145  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_90...
#
#                               filename solvent speed grooves sample_phi  \
# 94     tol_hi_nogr_0_01190652_0002.tif     tol    hi    nogr          0
# 101  tol_hi_nogr_90b_01190639_0002.tif     tol    hi    nogr          0
# 108   tol_hi_nogr_90_01190630_0002.tif     tol    hi    nogr         90
# 122    tol_hi_par_0__01171334_0003.tif     tol    hi     par          0
# 129   tol_hi_par_90__01171317_0002.tif     tol    hi     par         90
# 131   tol_hi_par_90__01171320_0002.tif     tol    hi     par         90
# 138   tol_hi_perp_0__01171546_0002.tif     tol    hi    perp          0
# 145  tol_hi_perp_90__01171536_0002.tif     tol    hi    perp         90
#
#      theta  exp_time                                           darkfile  \
# 94    0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 101   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 108   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 122   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 129   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 131   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 138   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
# 145   0.12        90  F:\N2200 Project\data\ssrl\dark90_01190715_000...
#
#           samplename  specnum  \
# 94     tol_hi_nogr_0        2
# 101  tol_hi_nogr_90b        2
# 108   tol_hi_nogr_90        2
# 122     tol_hi_par_0        3
# 129    tol_hi_par_90        2
# 131    tol_hi_par_90        2
# 138    tol_hi_perp_0        2
# 145   tol_hi_perp_90        2
#
#                                               datapath  \
# 94   F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_0_...
# 101  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 108  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 122  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_0__...
# 129  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 131  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 138  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_0_...
# 145  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_90...
#
#                                               darkpath  \
# 94   F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_0_...
# 101  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 108  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 122  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_0__...
# 129  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 131  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 138  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_0_...
# 145  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_90...
#
#                                                logpath
# 94   F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_0_...
# 101  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 108  F:\N2200 Project\data\ssrl\waxs\tol_hi_nogr_90...
# 122  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_0__...
# 129  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 131  F:\N2200 Project\data\ssrl\waxs\tol_hi_par_90_...
# 138  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_0_...
# 145  F:\N2200 Project\data\ssrl\waxs\tol_hi_perp_90...

# %%
for i,r in df_analysis.iterrows():
    print('running {}'.format(r.samplename))
    try:
        new_row = analyze_n22(r,df_peak_init)
        df_res = df_res.append(new_row, ignore_index=True)
        print('Hermans = {}'.format(new_row['Hermans']))
    except:
        print('{} failed'.format(r.samplename))
        pass
# Out:
# running tol_hi_nogr_0
# Hermans = 0.20811362410122947
# running tol_hi_nogr_90b
# Hermans = 0.2432396745267903
# running tol_hi_nogr_90
# Hermans = 0.2430949964464107
# running tol_hi_par_0
# Hermans = 0.19064970495381284
# running tol_hi_par_90
# Hermans = 0.36605006956855884
# running tol_hi_par_90
# Hermans = 0.3957792379878616
# running tol_hi_perp_0
# Hermans = 0.23692201494064874
# running tol_hi_perp_90
# Hermans = 0.18856427555206076

# %%
df_grouped = df_res.groupby('samplename').agg({'specnum':'max'})
df_grouped = df_grouped.reset_index()
df_grouped = df_grouped.rename(columns = {'specnum':'specnum_max'})
df_res2 = pd.merge(df_res, df_grouped, how='left', on='samplename')
df_res2 = df_res2[df_res2['specnum']==df_res2['specnum_max']]
# df_res2 = df_res2.drop([29,37])
df_res2['ratio_001_200'] = df_res2['peak_fits'].apply(lambda df: df['amplitude'].loc[df.name=='p100'].iloc[0] /
                                                                 df['amplitude'].loc[df.name=='p001'].iloc[0])
df_res2['amp100'] = df_res2['peak_fits'].apply(lambda df: df['amplitude'].loc[df.name=='p100'].iloc[0])
df_res2['amp001'] = df_res2['peak_fits'].apply(lambda df: df['amplitude'].loc[df.name=='p001'].iloc[0])

df_nospin = df_res2.loc[df_res2['grooves']!='none']
# df_nospin[['samplename','filename','ratio_001_200']]
df_res2[['samplename','filename','amp100','amp001','ratio_001_200','Hermans']]
# Out:
#         samplename                           filename       amp100  \
# 0    tol_hi_nogr_0    tol_hi_nogr_0_01190652_0002.tif  3931.018617
# 1  tol_hi_nogr_90b  tol_hi_nogr_90b_01190639_0002.tif   493.101319
# 2   tol_hi_nogr_90   tol_hi_nogr_90_01190630_0002.tif   493.511804
# 3     tol_hi_par_0    tol_hi_par_0__01171334_0003.tif  6647.088537
# 4    tol_hi_par_90   tol_hi_par_90__01171317_0002.tif     2.509378
# 5    tol_hi_par_90   tol_hi_par_90__01171320_0002.tif    22.025798
# 6    tol_hi_perp_0   tol_hi_perp_0__01171546_0002.tif  1525.173648
# 7   tol_hi_perp_90  tol_hi_perp_90__01171536_0002.tif  3545.501660
#
#        amp001  ratio_001_200   Hermans
# 0   69.245991      56.768898  0.208114
# 1  400.922687       1.229916  0.243240
# 2  362.635616       1.360903  0.243095
# 3    0.532297   12487.565537  0.190650
# 4    0.209755      11.963393  0.366050
# 5  548.626338       0.040147  0.395779
# 6  291.631190       5.229803  0.236922
# 7  169.442346      20.924531  0.188564

# %%
plt.subplot(1,2,1)
show_sample(47,df_res2)
plt.subplot(1,2,2)
show_sample(62,df_res2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-b540fcad05d6> in <module>()
#       1 plt.subplot(1,2,1)
# ----> 2 show_sample(47,df_res2)
#       3 plt.subplot(1,2,2)
#       4 show_sample(62,df_res2)
#
# <ipython-input-7-14927ea9c930> in show_sample(sample, df_master, newfig)
#       4     clim = np.percentile(logimg[logimg>0], (0.5, 99.9))
#       5
# ----> 6     ppl.implot(logimg, qxy, qz,
#       7                mode='rsma', cmap="terrain", clim=clim,
#       8                xlim=(-.6,2), ylim=(-0.05,2), newfig=newfig)
#
# NameError: name 'qxy' is not defined
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "

# %%
peak_test = 23
angle = 86
df_pex, out_dict_ex, x, y = fit_sector_peaks(peak_test,df_nospin,angle,df_peak_init, chi_width=4)
plot_peak_fits(x,y,df_pex,out_dict_ex)

# %%
show_sample(39,df_nospin)

# %%
df_master.loc[peak_test]

# %%
plt.figure()
plt.plot(df_nospin.ratio_001_200[::2],df_nospin.ratio_001_200[1::2],'ob')

# %%
df_g2 = df_res2.groupby(['solvent','speed','grooves'])
df_res2['df_g2.apply(lambda df: df.loc[df['sample_phi']==90].iloc[0] / 
                        df.loc[df['sample_phi']==0].iloc[0])

# %%
df_pole = pd.DataFrame()
df_prev = df_peak_init

for d in range(88,80,-2):
    
    print(d)
    df_curr = fit_sector_peaks(sample,df_master,d,df_prev,chi_width=4,radial_range=(1.35,20))
    df_pole = df_pole.append(df_curr)
    df_prev = df_curr

# %%
df_pole[df_pole.chi==86]

# %%
plt.figure()
plt.plot(df_pole[df_pole.name=='p100'].chi,df_pole[df_pole.name=='p100'].amplitude)

# %% [markdown]
# ### Compute d-spacing, Herman's Orientation

# %%
df['d-space']=2*np.pi / df['center'] * 10
df

# %% [markdown]
# ### Chi-profile, radially integrated, for Herman's calculation

# %%
p200_q = float(df['center'][df['name']=='p200'])

cake, chi = pg.profile_chi(data, npt=200,
                           radial_pos=p200_q, radial_width=.3,
                           chi_range=(-88,88),
                           correctSolidAngle=True,
                           method='lut', dark=dark)

ppl.plot(chi,np.abs(interp_nans(cake) * np.sin(np.deg2rad(chi))),mode='chi')
print('Hermans Orientation Factor: ', Hermans(interp_nans(cake),chi))

# %% [markdown]
# ### q-chi map, just because it's possible

# %%
intensity, q_abs, chi = pg.transform_polar(data,
                                           npt=(2000, 400), q_range=(0,20),
                                           correctSolidAngle=True,
                                           method='splitpix', dark=dark)

ppl.implot(intensity, q_abs, chi, mode='polar', cmap='terrain', clim=np.percentile(intensity,(0.1,99.5)))
# Out:
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\pygix-0.1.4a0-py3.6.egg\pygix\plotting.py:346: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif clim == 'auto':
# C:\Users\nep1\anaconda3\envs\xray\lib\site-packages\matplotlib\figure.py:2022: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   warnings.warn("This figure includes Axes that are not compatible "
# (<matplotlib.figure.Figure at 0xb98a898>,
#  <matplotlib.image.AxesImage at 0x16139048>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x166b31d0>)

# %% [markdown]
# ### Generate cropped, processed spectrum for all files
#
# Previous cells must have been run for this to work.

# %%
for ind,row in df_master.iterrows():
    
    data = fabio.open(row['fullpath']).data
    data = np.flipud(data)
    
    if row['exp_time'] == 30:
        dark = np.flipud(fabio.open(dark30file).data)
    else: 
        dark = np.flipud(fabio.open(dark90file).data)
    
    pg = pygix.Transform(dist = sdd, poni1 = poni1, poni2 = poni2,
                         rot1 = rot1, rot2 = rot2, rot3 = rot3,
                         wavelength = wl, sample_orientation = sample_orientation,
                         incident_angle = incident_angle, tilt_angle = tilt_angle,
                         detector=detector)

    imgt, qxy, qz = pg.transform_reciprocal(data, method='lut', correctSolidAngle=True, unit='A', dark=dark)
    corrimg = imgt-np.min(imgt)+1
    logimg = np.log(corrimg)
    
    figfile = (row['fullpath'].split('.')[:-1][0]+'.png').replace('data','figures')
    print(figfile)
    clim = np.percentile(logimg[logimg>0], (0.5, 99.9))
    ppl.implot(logimg,qxy,qz,mode='rsma',cmap='terrain',clim=clim,xlim=(-.6,2),ylim=(-.05,2),show=False,filename=figfile)
    plt.close()

# %%
df_res.to_csv(path_or_buf='n22_waxs_results.csv')

# %%
df_res.to_pickle('n22_waxs_pickle')

# %%
df_new = pd.read_pickle('n22_waxs_pickle')
df_new

# %%
df_new
